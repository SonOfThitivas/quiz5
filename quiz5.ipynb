# %% [markdown]
# 1. Implement a PostfixtoPrefix(postfix_exp) function that converts postfix to prefix expression.

# %%
class Empty(Exception):
    """Error attempting to access an element from an empty container."""
    pass

class ArrayStack:
    """LIFO Stack implementation using a Python list as underlying storage."""

    def __init__(self):
        """Create an empty stack."""
        self.data = []

    def __len__(self):
        """Return the number of elements in the stack."""
        return len(self.data)

    def is_empty(self):
        """Return True if the stack is empty."""
        return len(self.data) == 0

    def push(self, e):
        """Add element e to the top of the stack."""
        self.data.append(e)

    def top(self):
        """Return (but do not remove) the element at the top of the stack.

        Raise Empty exception if the stack is empty.
        """
        if self.is_empty():
            Exception("Stack is empty")
        return self.data[len(self.data - 1)]
        
    def pop(self):
        """Remove and return the element from the top of the stack (i.e., LIFO).

        Raise Empty exception if the stack is empty.
        """
        if self.is_empty():
            Exception("Stack is empty")
        return self.data.pop()
        
def PostfixtoPrefix(postfix_exp): 
    '''Convert postfix to prefix expression'''
    stack = ArrayStack()
    
    for token in postfix_exp:
        if token not in ['+','-','/','*','^']:
            stack.push(token)
        else:
            temp_stack = ArrayStack()
            temp_stack.push(token)
            operand2, operand1 = stack.pop(), stack.pop()
            temp_stack.push(operand1)
            temp_stack.push(operand2)
            stack.push("".join(temp_stack.data))
            
    return "".join(stack.data)

# %% [markdown]
# 2.Implement a evaluatePrefix(prefix_exp) function that evaluates prefix expression.

# %%
class Empty(Exception):
    """Error attempting to access an element from an empty container."""
    pass

class ArrayStack:
    """LIFO Stack implementation using a Python list as underlying storage."""

    def __init__(self):
        """Create an empty stack."""
        self.data = []

    def __len__(self):
        """Return the number of elements in the stack."""
        return len(self.data)

    def is_empty(self):
        """Return True if the stack is empty."""
        return len(self.data) == 0

    def push(self, e):
        """Add element e to the top of the stack."""
        self.data.append(e)

    def top(self):
        """Return (but do not remove) the element at the top of the stack.

        Raise Empty exception if the stack is empty.
        """
        if self.is_empty():
            Exception("Stack is empty")
        return self.data[len(self.data - 1)]
        
    def pop(self):
        """Remove and return the element from the top of the stack (i.e., LIFO).

        Raise Empty exception if the stack is empty.
        """
        if self.is_empty():
            Exception("Stack is empty")
        return self.data.pop()
        
def evaluatePrefix(prefix_exp): 
    '''Evaluate prefix expression'''
    prefix_exp = prefix_exp[-1::-1]
    
    stack = ArrayStack()

    for token in prefix_exp:
        if token not in ['+','-','*','/','^']:
            stack.push(token)
        else:
            operand1, operand2 = stack.pop(), stack.pop()
            stack.push(str(eval(operand1 + token + operand2)))
            
    return float(stack.pop())

# %% [markdown]
# 3.Implement a InfixtoPostfix(inxfix_exp) function that converts infix to postfix expression.

# %%
class Empty(Exception):
    """Error attempting to access an element from an empty container."""
    pass

class ArrayStack:
    """LIFO Stack implementation using a Python list as underlying storage."""

    def __init__(self):
        """Create an empty stack."""
        self.data = []

    def __len__(self):
        """Return the number of elements in the stack."""
        return len(self.data)

    def is_empty(self):
        """Return True if the stack is empty."""
        return len(self.data) == 0

    def push(self, e):
        """Add element e to the top of the stack."""
        self.data.append(e)

    def top(self):
        """Return (but do not remove) the element at the top of the stack.

        Raise Empty exception if the stack is empty.
        """
        if self.is_empty():
            Exception("Stack is empty")
        else:
            return self.data[-1]
        
    def pop(self):
        """Remove and return the element from the top of the stack (i.e., LIFO).

        Raise Empty exception if the stack is empty.
        """
        if self.is_empty():
            Exception("Stack is empty")
        return self.data.pop()
        
def InfixtoPostfix(inxfix_exp): 
    '''Evaluate infix expression'''
    postfix_exp = ArrayStack()
    operator_stack = ArrayStack()
    
    for token in inxfix_exp:
        if token == '(':
            operator_stack.push(token)
        elif token == ')':
            operator = operator_stack.pop()
            while operator != '(':
                operand2, operand1 = postfix_exp.pop(), postfix_exp.pop()
                postfix_exp.push(operand1+operand2+operator)
                operator = operator_stack.pop()
        elif (token == '^' and operator_stack.top() in ['+','-','*','/','^']) or (token in "+-" and operator_stack.top() in ['*','/','+','-']):
            while (token == '^' and operator_stack.top() in ['+','-','*','/','^']) or (token in "+-" and operator_stack.top() in ['*','/','+','-']):
                operand2, operand1, operator = postfix_exp.pop(), postfix_exp.pop(), operator_stack.pop()
                postfix_exp.push(operand1+operand2+operator)
                
            operator_stack.push(token)
        elif token in "+-*/^":
            operator_stack.push(token)
        else:
            postfix_exp.push(token)
    
    # pop all operators at last
    while not (operator_stack.is_empty()):
        postfix_exp.push(operator_stack.pop())
          
    return "".join(postfix_exp.data)

# %% [markdown]
# 4. Implement a InfixtoPrefix(inxfix_exp) function that converts infix to prefix expression.

# %%
class Empty(Exception):
    """Error attempting to access an element from an empty container."""
    pass

class ArrayStack:
    """LIFO Stack implementation using a Python list as underlying storage."""

    def __init__(self):
        """Create an empty stack."""
        self.data = []

    def __len__(self):
        """Return the number of elements in the stack."""
        return len(self.data)

    def is_empty(self):
        """Return True if the stack is empty."""
        return len(self.data) == 0

    def push(self, e):
        """Add element e to the top of the stack."""
        self.data.append(e)

    def top(self):
        """Return (but do not remove) the element at the top of the stack.

        Raise Empty exception if the stack is empty.
        """
        if self.is_empty():
            Exception("Stack is empty")
        else:
            return self.data[-1]
        
    def pop(self):
        """Remove and return the element from the top of the stack (i.e., LIFO).

        Raise Empty exception if the stack is empty.
        """
        if self.is_empty():
            Exception("Stack is empty")
        return self.data.pop()
        
def InfixtoPrefix(inxfix_exp): 
    '''Evaluate infix expression'''
    prefix_exp = ArrayStack()
    operator_stack = ArrayStack()
    inxfix_exp = inxfix_exp[-1::-1]
    
    for token in inxfix_exp:
        if token == ')':
            operator_stack.push(token)
        elif token == '(':
            operator = operator_stack.pop()
            while operator != ')':
                operand2, operand1 = prefix_exp.pop(), prefix_exp.pop()
                prefix_exp.push(operand1+operand2+operator)
                operator = operator_stack.pop()
        elif (token == '^' and operator_stack.top() in ['+','-','*','/','^']) or (token in "+-" and operator_stack.top() in ['*','/','+','-']):
            while (token == '^' and operator_stack.top() in ['+','-','*','/','^']) or (token in "+-" and operator_stack.top() in ['*','/','+','-']):
                operand2, operand1, operator = prefix_exp.pop(), prefix_exp.pop(), operator_stack.pop()
                prefix_exp.push(operand1+operand2+operator)
                
            operator_stack.push(token)
        elif token in "+-*/^":
            operator_stack.push(token)
        else:
            prefix_exp.push(token)
    
    # pop all operators at last
    while not (operator_stack.is_empty()):
        prefix_exp.push(operator_stack.pop())
          
    return "".join(prefix_exp.data)[-1::-1]

# %% [markdown]
# 5. Implement a evaluateInfix(inxfix_exp) function that evaluates infix expression.

# %%
class Empty(Exception):
    """Error attempting to access an element from an empty container."""
    pass

class ArrayStack:
    """LIFO Stack implementation using a Python list as underlying storage."""

    def __init__(self):
        """Create an empty stack."""

    def __len__(self):
        """Return the number of elements in the stack."""

    def is_empty(self):
        """Return True if the stack is empty."""

    def push(self, e):
        """Add element e to the top of the stack."""

    def top(self):
        """Return (but do not remove) the element at the top of the stack.

        Raise Empty exception if the stack is empty.
        """
        
    def pop(self):
        """Remove and return the element from the top of the stack (i.e., LIFO).

        Raise Empty exception if the stack is empty.
        """
def evaluateInfix(inxfix_exp): 
    '''Evaluate infix expression'''
    return float(eval(inxfix_exp))
